# %%
import random

# %%
str = ""
for i in range(18):
    ch = chr(random.randrange(ord('0'), ord('9') + 1))
    str += ch
 
print(str)
# Out:
# 727001681839435860

# %%
import csv

# %%
# 1. 创建文件对象
f = open('id.csv','w',encoding='utf-8')

# %%
# 2. 基于文件对象构建 csv写入对象
csv_writer = csv.writer(f)

# %%
# 3. 构建列表头
csv_writer.writerow(["CARD_ID"])
# Out:
# 9

# %%
# 4. 写入csv文件内容
csv_writer.writerow(["620422199901011474"])
# Out:
# 20

# %%
# 5. 关闭文件
f.close()

# %%
import pandas as pd

# %%
data = pd.read_csv("id.csv")

# %%
data
# Out:
# Empty DataFrame
# Columns: [620422199901011474]
# Index: []

# %%
import csv
import pandas as pd
import random

# 1. 创建文件对象
f = open('id.csv','w',encoding='utf-8')

# 2. 基于文件对象构建 csv写入对象
csv_writer = csv.writer(f)
# 3. 构建列表头
csv_writer.writerow(["CARD_ID"])

# 4. 写入csv文件内容
# csv_writer.writerow(["620422199901011474"])

for m in range(100): 
    str = ""
    for i in range(18):
        ch = chr(random.randrange(ord('0'), ord('9') + 1))
        str += ch
    
    csv_writer.writerow([str])
    
# 5. 关闭文件
f.close()

data = pd.read_csv("id.csv")

# %%
data
# Out:
#                CARD_ID
# 0   677389910165510032
# 1   993558212259578465
# 2   150657654569871747
# 3   973996981260937764
# 4   146028614051732430
# 5   329853961871256354
# 6   152205754170080073
# 7    66159176375001787
# 8   495758279711074806
# 9   599973773552086019
# 10  318378654669976016
# 11   54167198133024048
# 12  830495784058738287
# 13  366337863087855159
# 14  437280154655733444
# 15  121303925234526867
# 16  357002576288956183
# 17  146146133383418034
# 18  748238973602674412
# 19  920815839786074897
# 20  462886519840966462
# 21  130675113572663905
# 22  116140574646503351
# 23   57044167087085317
# 24  549024840568526303
# 25  842355961113466638
# 26  865969110822622089
# 27  770136289927857608
# 28  410036611090949207
# 29  337387322666876217
# ..                 ...
# 70  984383570826932293
# 71  523000190422272712
# 72  354721885690550665
# 73   74143666085473963
# 74  652780216888176305
# 75  430052792569664017
# 76  264382218317443207
# 77   56062362216302507
# 78  527632391018694563
# 79  362230289759115941
# 80  206703919384965427
# 81  314444613790607643
# 82  854526216545947517
# 83  966158227319627513
# 84  889768804451072338
# 85  275009785837236439
# 86  177716179131764654
# 87  176620448911724489
# 88  620165154263165633
# 89  744501578161146313
# 90  520925495942098805
# 91  640833377549292225
# 92  941401371116923377
# 93  542792032823143330
# 94  262543603712644406
# 95   83818186138930365
# 96  706597984049975676
# 97   22702724501607179
# 98  233502877672611794
# 99  559703371375244069
#
# [100 rows x 1 columns]

# %%
# from gmssl import sm3, func
# strs = "20210201173824975258"
# str_b = bytes(strs, encoding='utf-8')
# result = sm3.sm3_hash(func.bytes_to_list(str_b))
# print(result)  #50f03b05d10fa07f1169aff1d1e119ae3169107035b1abd24f76009ee05a8e2c

# %%
# def sm3(strs):
# #     strs = "20210201173824975258"
#     str_b = bytes(strs, encoding='utf-8')
#     result = sm3.sm3_hash(func.bytes_to_list(str_b))
#     print(result)  #50f03b05d10fa07f1169aff1d1e119ae3169107035b1abd24f76009ee05a8e2c

# %%
# strs1 = "20210201173824975258"
# sm3(strs1)

# %%
data.iloc[1, 0] # 获取第二行第二列的值
# data.iat[1, 1] # 获取第二行第二列的值，效果与iloc()相同
# Out:
df.insert(1, "ID", "")

# %%
df
# Out:
#                CARD_ID ID
# 0   677389910165510032
# 1   993558212259578465
# 2   150657654569871747
# 3   973996981260937764
# 4   146028614051732430
# 5   329853961871256354
# 6   152205754170080073
# 7    66159176375001787
# 8   495758279711074806
# 9   599973773552086019
# 10  318378654669976016
# 11   54167198133024048
# 12  830495784058738287
# 13  366337863087855159
# 14  437280154655733444
# 15  121303925234526867
# 16  357002576288956183
# 17  146146133383418034
# 18  748238973602674412
# 19  920815839786074897
# 20  462886519840966462
# 21  130675113572663905
# 22  116140574646503351
# 23   57044167087085317
# 24  549024840568526303
# 25  842355961113466638
# 26  865969110822622089
# 27  770136289927857608
# 28  410036611090949207
# 29  337387322666876217
# ..                 ... ..
# 70  984383570826932293
# 71  523000190422272712
# 72  354721885690550665
# 73   74143666085473963
# 74  652780216888176305
# 75  430052792569664017
# 76  264382218317443207
# 77   56062362216302507
# 78  527632391018694563
# 79  362230289759115941
# 80  206703919384965427
# 81  314444613790607643
# 82  854526216545947517
# 83  966158227319627513
# 84  889768804451072338
# 85  275009785837236439
# 86  177716179131764654
# 87  176620448911724489
# 88  620165154263165633
# 89  744501578161146313
# 90  520925495942098805
# 91  640833377549292225
# 92  941401371116923377
# 93  542792032823143330
# 94  262543603712644406
# 95   83818186138930365
# 96  706597984049975676
# 97   22702724501607179
# 98  233502877672611794
# 99  559703371375244069
#
# [100 rows x 2 columns]

# %%
from gmssl import sm3, func

# %%
def dataSm3(strs):
    str_b = bytes(strs, encoding='utf-8')
    result = sm3.sm3_hash(func.bytes_to_list(str_b))
    return result;

#     print(result)  #50f03b05d10fa07f1169aff1d1e119ae3169107035b1abd24f76009ee05a8e2c

# %%
strs = "20210201173824975258"
a = dataSm3(strs)

# %%
a
# Out:
# '50f03b05d10fa07f1169aff1d1e119ae3169107035b1abd24f76009ee05a8e2c'

# %%
data.iloc[g,0]
# Out:
# 559703371375244069

# %%
type(data.iloc[g,0])
# Out:
# numpy.int64

# %%
b= data.iloc[g,0]
b
# b = .tostring()
# Out:
# 559703371375244069

# %%
c = b.tostring

# %%
c
# Out:
# <function int64.tostring>

# %%
data.iloc[0,0]
# Out:
# 677389910165510032

# %%
aa = data.iloc[0,0]

# %%
bb = aa.tostring

# %%
bb
# Out:
# <function int64.tostring>

# %%
type(c)
# Out:
# builtin_function_or_method

# %%
for g in range(data.shape[0]):
    print(data.iloc[g,0])
    aa = data.iloc[g,0]
    bb = aa.tostring
    a = dataSm3(bb)
    df.iloc[g,1] = a
# Out:
# 677389910165510032
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-300193f0be8a> in <module>()
#       3     aa = data.iloc[g,0]
#       4     bb = aa.tostring
# ----> 5     a = dataSm3(bb)
#       6     df.iloc[g,1] = a
#
# <ipython-input-13-c064540f5108> in dataSm3(strs)
#       1 def dataSm3(strs):
# ----> 2     str_b = bytes(strs, encoding='utf-8')
#       3     result = sm3.sm3_hash(func.bytes_to_list(str_b))
#       4     return result;
#       5
#
# TypeError: encoding without a string argument

# %%
from gmssl import sm3, func
strs = "181767976089766314"
str_b = bytes(strs, encoding='utf-8')
result = sm3.sm3_hash(func.bytes_to_list(str_b))
print(result)  #50f03b05d10fa07f1169aff1d1e119ae3169107035b1abd24f76009ee05a8e2c
# Out:
# de1764863714632827103c6c893187782df3e1b45a1160e08c540b27e341e2e9

# %%
103222433129854932
